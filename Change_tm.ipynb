# %%
import utils
import pandas as pd

# %%
_, _, _, transition = utils.upload_data()

# %% [markdown]
# The following code deminstrates the manipulations damn

# %%
transition
# Out:
#          AAA     AA      A    BBB     BB      B  CCC/C    Def     NR
# AAA    87.06   9.06   0.53   0.05   0.11   0.03   0.05   0.00   3.11
# AA      0.48  87.23   7.77   0.47   0.05   0.06   0.02   0.02   3.89
# A       0.03   1.60  88.58   5.00   0.26   0.11   0.02   0.05   4.35
# BBB     0.00   0.09   3.25  86.49   3.56   0.43   0.10   0.16   5.92
# BB      0.01   0.03   0.11   4.55  77.82   6.80   0.55   0.63   9.51
# B       0.00   0.02   0.07   0.15   4.54  74.60   4.96   3.34  12.33
# CCC/C   0.00   0.00   0.10   0.17   0.55  12.47  43.11  28.30  15.31

# %%
utils.change_TM(transition)
# Out:
# /Users/rickyyung/MFM 714 project/MFM-714-Project/utils.py:220: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   da_new_2 =  matrix * np.reciprocal(np.sum(matrix,axis=1)[:,np.newaxis])
# /Users/rickyyung/MFM 714 project/MFM-714-Project/utils.py:227: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   adjustment=da_new * missing[:,None]
#              AAA         AA          A        BBB         BB          B  \
# AAA    89.514964   9.349845   0.546956   0.330237   0.113519   0.082559
# AA      0.499480  90.546328   8.085328   0.489074   0.275732   0.062435
# A       0.031364   1.672765  92.608468   5.227392   0.271824   0.115003
# BBB     0.000000   0.095663   3.454507  91.932398   3.784014   0.457058
# ...
